# %%
import requests
from bs4 import BeautifulSoup
import bs4
import json
from urllib.parse import urljoin
import logging
import traceback

# %% [markdown]
# ### Crawl a class

# %%
DEBUG = False

class ClassDocCrawler:
    def __init__(self) -> None:
        pass
            
    def CrawlClass(self, InClassDocUrl : str, data=[]):
        if not InClassDocUrl:
            logging.warning(f"In class doc url invalid {InClassDocUrl}")
            return data
        CurrentPageUrl = InClassDocUrl
        self.PageUrl = InClassDocUrl
        response = requests.get(CurrentPageUrl)
        soup = BeautifulSoup(response.text, 'html.parser', from_encoding="ISO-8859-1")
        paragraphs = soup.find_all('p')
        HeaderName, ModuleName, IncludePath = None, None, None
        ClassName = None
        Title = soup.find("div", attrs={"id" : "pageTitle"})
        if Title:
            ClassName = Title.text
        for idx, node in enumerate(paragraphs):
            # print(node.text)
            if node.text == "Header" and idx < len(paragraphs) - 1:
                HeaderName = paragraphs[idx + 1].text
            if node.text == "Module" and idx < len(paragraphs) - 1:
                ModuleName = paragraphs[idx + 1].text
            if node.text == "Include" and idx < len(paragraphs) - 1:
                IncludePath = paragraphs[idx + 1].text
            
            
        Rows = soup.find_all('tr',attrs={"class":"normal-row"})

        for Row in Rows[3:]:
            Description, Type, Name = self.ExtractFromRow(Row)
            if Name is None:
                continue
            data.append({
                "Module" : ModuleName,
                "HeaderPath" : IncludePath,
                "ClassName" : ClassName,
                "Name": Name,
                "Type": Type,
                "Description": Description,
            })
            if DEBUG:
                break
            
        return data

    def FilterText(self, InText : str) -> str:
        return InText.replace('Â', '').replace('\u00a0','').replace('\n\n','').strip('\n\u00a0\t\n\r')

    def IsShortened(self, InText: str) -> bool:
        return InText.endswith("...")

    def FindFullNameFromUrl(self, InTag: bs4.element.Tag) -> str:
        UrlTag = InTag.find('a')
        
        if not UrlTag:
            return self.FilterText(InTag.text)
        
        RelUrl = UrlTag.get('href')
        ResultUrl = urljoin(self.PageUrl, RelUrl)
        
        DetailResponse = requests.get(ResultUrl)
        DetailSoup = BeautifulSoup(DetailResponse.text, 'html.parser', from_encoding="ISO-8859-1")
        Name = DetailSoup.find('h1',attrs={'id' : 'H1TitleId'})
        if not Name:
            return InTag.text
        return Name.text
    
    def ExtractFromRow(self, Row: bs4.element.Tag) -> None:
        Descriptions = Row.find_all("td", attrs={"class" : "desc-cell"})
        Other = Row.find_all("td", attrs={"class" : "name-cell"})
        
        if len(Descriptions) != 1 or len(Other) != 2:
            # print(Row,"\n __________ \n")
            return None, None, None
        
        Description = self.FilterText( Descriptions[0].text)
        Type = self.FilterText(Other[0].text)
        Name = self.FilterText(Other[1].text)
        
        if self.IsShortened(Description):
            Description = self.FindFullNameFromUrl(Descriptions[0])
        if self.IsShortened(Type):
            Type = self.FindFullNameFromUrl(Other[0])
        if self.IsShortened(Name):
            Name = self.FindFullNameFromUrl(Other[1])
        
        return Description, Type, Name

# %% [markdown]
# ### Crawl content from every Class from module

# %%
def CrawlModule(ModuleDocUrl : str, data = []):
    ClassCrawler = ClassDocCrawler()
    
    response = requests.get(ModuleDocUrl)
    Soup = BeautifulSoup(response.text, 'html.parser')
    
    ClassSection = Soup.find("div", attrs={"id" : "classes"})
    if not ClassSection:
        print(f"no class section in {ModuleDocUrl}")
        return
    ClassTags = ClassSection.find_all('td', attrs={"class" : "name-cell"})
    for ClassTag in ClassTags:
        ClassUrlTag = ClassTag.find('a')
        if not ClassUrlTag:
            print(f"not found class urltag{ClassTag}")
            continue
        RelClassDocUrl = ClassUrlTag.get("href")
        FullClassUrl = urljoin(ModuleDocUrl, RelClassDocUrl)
        ClassCrawler.CrawlClass(FullClassUrl, data)
        if DEBUG:
            break
        
    return

# %% [markdown]
# ### Crawl every module

# %%
StartCrawlFlag = False

def CrawlEveryModule(DocUrl="https://docs.unrealengine.com/4.27/en-US/API/", data = [], continueAt = None):
    global StartCrawlFlag
    Response = requests.get(DocUrl)
    Soup = BeautifulSoup(Response.text, "html.parser")
    ModulelistTags = Soup.find_all("div", attrs={"class" : "modules-list"})
    try:
        for Modulelist in ModulelistTags:
            UrlTags = Modulelist.find_all("td", attrs={"class" : "name-cell"})
            for UrlTag in UrlTags:
                if continueAt:
                    ModuleName = (UrlTag.text).strip("\n")
                    if continueAt == ModuleName:
                        StartCrawlFlag = True
                    if not StartCrawlFlag:
                        print(f"skip {ModuleName}")
                        continue
                RelUrlTag = UrlTag.find('a')
                if not RelUrlTag:
                    continue
                RelUrl = RelUrlTag.get("href")
                ModuleUrl = urljoin(DocUrl, RelUrl)
                if not RelUrl:
                    print(UrlTag)
                    continue
                print(ModuleUrl,RelUrl)
                CrawlModule(ModuleUrl, data)
                if DEBUG:
                    break
        return data
    except:
        traceback.print_exc()
        return data

# %%
# NewData = CrawlEveryModule(continueAt="Engine")


# with open('output2.json', 'w') as f:
#     json.dump(NewData, f, indent=4)

# %%
# NewData = CrawlEveryModule(continueAt="Sequencer")
# with open('output3.json', 'w') as f:
#     json.dump(NewData, f, indent=4)

# %%
# NewData = CrawlEveryModule(continueAt="DisplayCluster")

# with open('output4.json', 'w') as f:
#     json.dump(NewData, f, indent=4)

# %%
NewData = CrawlEveryModule(continueAt="DynamicMesh")

with open('output5.json', 'w') as f:
    json.dump(NewData, f, indent=4)
# Out:
# skip Advertising
# skip AIModule
# skip Analytics
# skip AnalyticsET
# skip AnalyticsVisualEditing
# skip AnimationCore
# skip AnimGraphRuntime
# skip AppFramework
# skip ApplicationCore
# skip AssetRegistry
# skip AudioAnalyzer
# skip AudioCaptureCore
# skip AudioCaptureRtAudio
# skip AudioExtensions
# skip AudioMixer
# skip AudioMixerCore
# skip AudioPlatformConfiguration
# skip AugmentedReality
# skip AutomationMessages
# skip AutomationWorker
# skip AVEncoder
# skip AVIWriter
# skip BlueprintRuntime
# skip BuildPatchServices
# skip BuildSettings
# skip Cbor
# skip CEF3Utils
# skip Chaos
# skip ChaosCore
# skip ChaosSolverEngine
# skip ChaosVehiclesCore
# skip ChaosVehiclesEngine
# skip CinematicCamera
# skip ClothingSystemRuntimeCommon
# skip ClothingSystemRuntimeInterface
# skip ClothingSystemRuntimeNv
# skip CookedIterativeFile
# skip Core
# skip CoreUObject
# skip CrunchCompression
# skip D3D12RHI
# skip DatasmithCore
# skip DeveloperSettings
# skip DirectLink
# skip Engine
# skip EngineMessages
# skip EngineSettings
# skip EyeTracker
# skip FieldSystemEngine
# skip Foliage
# skip GameplayMediaEncoder
# skip GameplayTags
# skip GameplayTasks
# skip GeForceNOWWrapper
# skip GeometryCollectionEngine
# skip HeadMountedDisplay
# skip HTTP
# skip HttpNetworkReplayStreaming
# skip HttpServer
# skip Icmp
# skip IESFile
# skip ImageCore
# skip ImageWrapper
# skip ImageWriteQueue
# skip InputCore
# skip InputDevice
# skip InstallBundleManager
# skip InteractiveToolsFramework
# skip Json
# skip JsonUtilities
# skip Landscape
# skip Launch
# skip LauncherPlatform
# skip LevelSequence
# skip LiveLinkInterface
# skip LiveLinkMessageBusFramework
# skip LocalFileNetworkReplayStreaming
# skip LuminRuntimeSettings
# skip MaterialShaderQualitySettings
# skip Media
# skip MediaAssets
# skip MediaInfo
# skip MediaUtils
# skip MeshDescription
# skip MeshUtilitiesCommon
# skip Messaging
# skip MessagingCommon
# skip MessagingRpc
# skip MoviePlayer
# skip MovieScene
# skip MovieSceneCapture
# skip MovieSceneTracks
# skip MRMesh
# skip NavigationSystem
# skip Navmesh
# skip NetCommon
# skip NetCore
# skip NetworkFile
# skip NetworkFileSystem
# skip Networking
# skip NetworkReplayStreaming
# skip NonRealtimeAudioRenderer
# skip NullDrv
# skip NullNetworkReplayStreaming
# skip OpenGLDrv
# skip Overlay
# skip PacketHandler
# skip PakFile
# skip PerfCounters
# skip PhysicsCore
# skip PhysXCooking
# skip PortalMessages
# skip PortalProxies
# skip PortalRpc
# skip PortalServices
# skip PreLoadScreen
# skip Projects
# skip PropertyAccess
# skip PropertyPath
# skip RawMesh
# skip ReliabilityHandlerComponent
# skip RenderCore
# skip Renderer
# skip RHI
# skip RigVM
# skip RSA
# skip SandboxFile
# skip Serialization
# skip SessionMessages
# skip SessionServices
# skip SignalProcessing
# skip Slate
# skip SlateCore
# skip SlateNullRenderer
# skip SlateRHIRenderer
# skip Sockets
# skip SoundFieldRendering
# skip SSL
# skip StageDataCore
# skip StaticMeshDescription
# skip StreamingFile
# skip StreamingPauseRendering
# skip SynthBenchmark
# skip TimeManagement
# skip Toolbox
# skip TraceLog
# skip UE4Game
# skip UMG
# skip UnrealAudio
# skip VectorVM
# skip Voice
# skip Voronoi
# skip VulkanRHI
# skip WebBrowser
# skip WebBrowserTexture
# skip WebSockets
# skip WidgetCarousel
# skip XmlParser
# skip ActorPickerMode
# skip AddContentDialog
# skip AdvancedPreviewScene
# skip AIGraph
# skip AnimationBlueprintEditor
# skip AnimationEditor
# skip AnimationModifiers
# skip AnimGraph
# skip AssetTagsEditor
# skip AudioEditor
# skip BehaviorTreeEditor
# skip BlueprintGraph
# skip Blutility
# skip Cascade
# skip ClassViewer
# skip ClothingSystemEditor
# skip ClothingSystemEditorInterface
# skip ClothPainter
# skip CommonMenuExtensions
# skip ComponentVisualizers
# skip ConfigEditor
# skip ContentBrowser
# skip ContentBrowserData
# skip CurveAssetEditor
# skip CurveEditor
# skip CurveTableEditor
# skip DataTableEditor
# skip DetailCustomizations
# skip DeviceProfileEditor
# skip DeviceProfileServices
# skip DistCurveEditor
# skip Documentation
# skip EditorInteractiveToolsFramework
# skip EditorSettingsViewer
# skip EditorStyle
# skip EditorSubsystem
# skip EditorWidgets
# skip EnvironmentLightingViewer
# skip FoliageEdit
# skip FontEditor
# skip GameplayTasksEditor
# skip GameProjectGeneration
# skip GraphEditor
# skip HardwareTargeting
# skip HierarchicalLODOutliner
# skip InputBindingEditor
# skip InternationalizationSettings
# skip IntroTutorials
# skip Kismet
# skip KismetCompiler
# skip KismetWidgets
# skip LandscapeEditor
# skip LandscapeEditorUtilities
# skip Layers
# skip LevelEditor
# skip LocalizationCommandletExecution
# skip LocalizationDashboard
# skip MainFrame
# skip MaterialEditor
# skip Matinee
# skip MergeActors
# skip MeshPaint
# skip MeshPaintMode
# skip MovieSceneCaptureDialog
# skip MovieSceneTools
# skip NewLevelDialog
# skip OverlayEditor
# skip PackagesDialog
# skip Persona
# skip PhysicsAssetEditor
# skip PIEPreviewDeviceProfileSelector
# skip PIEPreviewDeviceSpecification
# skip PinnedCommandList
# skip PixelInspectorModule
# skip PlacementMode
# skip PListEditor
# skip PluginWarden
# skip ProjectSettingsViewer
# skip ProjectTargetPlatformEditor
# skip PropertyEditor
# skip SceneDepthPickerMode
# skip SceneOutliner
# skip Sequencer
# skip SequenceRecorder
# skip SequencerWidgets
# skip SerializedRecorderInterface
# skip SkeletalMeshEditor
# skip SkeletonEditor
# skip SourceControlWindows
# skip StaticMeshEditor
# skip StatsViewer
# skip StringTableEditor
# skip StructViewer
# skip SwarmInterface
# skip TextureEditor
# skip TimeManagementEditor
# skip ToolMenusEditor
# skip TranslationEditor
# skip UATHelper
# skip UMGEditor
# skip UndoHistory
# skip UnrealEd
# skip UnrealEdMessages
# skip ViewportInteraction
# skip ViewportSnapping
# skip VirtualTexturingEditor
# skip VREditor
# skip WorkspaceMenuStructure
# skip WorldBrowser
# skip AITestSuite
# skip AllDesktopTargetPlatform
# skip AssetTools
# skip AudioFormatADPCM
# skip AudioFormatOgg
# skip AudioFormatOpus
# skip AudioSettingsEditor
# skip AutomationController
# skip AutomationWindow
# skip BlueprintCompilerCppBackend
# skip BlueprintNativeCodeGen
# skip CollectionManager
# skip CollisionAnalyzer
# skip DatasmithExporter
# skip DerivedDataCache
# skip DesktopPlatform
# skip DesktopWidgets
# skip DeviceManager
# skip DirectoryWatcher
# skip EditorAnalyticsSession
# skip ExternalImagePicker
# skip FileUtilities
# skip FunctionalTesting
# skip GameplayDebugger
# skip GammaUI
# skip GraphColor
# skip HierarchicalLODUtilities
# skip HotReload
# skip IoStoreUtilities
# skip LauncherServices
# skip Localization
# skip LocalizationService
# skip LogVisualizer
# skip LuminPlatformEditor
# skip LuminTargetPlatform
# skip MaterialBaking
# skip MaterialUtilities
# skip Merge
# skip MeshBoneReduction
# skip MeshBuilder
# skip MeshBuilderCommon
# skip MeshMergeUtilities
# skip MeshReductionInterface
# skip MeshUtilities
# skip MessageLog
# skip ModuleUI
# skip OutputLog
# skip PakFileUtilities
# skip Profiler
# skip ProfilerClient
# skip ProfilerMessages
# skip ProfilerService
# skip ProjectLauncher
# skip QuadricMeshReduction
# skip RealtimeProfiler
# skip RigVMDeveloper
# skip ScreenShotComparison
# skip ScreenShotComparisonTools
# skip ScriptDisassembler
# skip SessionFrontend
# skip Settings
# skip SettingsEditor
# skip ShaderCompilerCommon
# skip ShaderFormatOpenGL
# skip ShaderFormatVectorVM
# skip ShaderPreprocessor
# skip SharedSettingsWidgets
# skip SkeletalMeshUtilitiesCommon
# skip SlateReflector
# skip SourceCodeAccess
# skip SourceControl
# skip StandaloneRenderer
# skip TargetDeviceServices
# skip TargetPlatform
# skip TaskGraph
# skip TextureCompressor
# skip TextureFormatASTC
# skip TextureFormatDXT
# skip TextureFormatETC2
# skip TextureFormatIntelISPCTexComp
# skip TextureFormatPVR
# skip TextureFormatUncompressed
# skip ToolMenus
# skip TraceAnalysis
# skip TraceInsights
# skip TraceServices
# skip TreeMap
# skip VulkanShaderFormat
# skip ActorLayerUtilities
# skip ActorLayerUtilitiesEditor
# skip ActorPalette
# skip ActorSequence
# skip ActorSequenceEditor
# skip AdjustEditor
# skip ADOSupport
# skip AESGCMHandlerComponent
# skip AESHandlerComponent
# skip AISupportModule
# skip AjaMedia
# skip AjaMediaEditor
# skip AjaMediaFactory
# skip AjaMediaOutput
# skip AlembicHairTranslatorModule
# skip AlembicImporter
# skip AlembicLibrary
# skip AnalyticsBlueprintLibrary
# skip AnalyticsMulticast
# skip AnalyticsMulticastEditor
# skip AndroidCameraEditor
# skip AndroidCameraFactory
# skip AndroidDeviceProfileSelector
# skip AndroidMediaEditor
# skip AndroidMediaFactory
# skip AndroidPermission
# skip AnimationBudgetAllocator
# skip AnimationSharing
# skip AnimationSharingEd
# skip AnimDistanceMatching
# skip Ansel
# skip ApexDestruction
# skip ApexDestructionEditor
# skip AppleARKit
# skip AppleARKitFaceSupport
# skip AppleARKitPoseTrackingLiveLink
# skip AppleImageUtils
# skip AppleImageUtilsBlueprintSupport
# skip AppleProResMedia
# skip AppleVision
# skip AppleVisionBlueprintSupport
# skip ArchVisCharacter
# skip ARUtilities
# skip AssetManagerEditor
# skip AssetSearch
# skip AssetTags
# skip AudioCapture
# skip AudioCaptureEditor
# skip AudioCaptureTimecodeProvider
# skip AudioModulation
# skip AudioModulationEditor
# skip AudioSynesthesia
# skip AudioSynesthesiaCore
# skip AudioSynesthesiaEditor
# skip AutomationUtils
# skip AutomationUtilsEditor
# skip AvfMediaEditor
# skip AvfMediaFactory
# skip AvidDNxMedia
# skip AxFImporter
# skip AzureSpatialAnchors
# skip BackChannel
# skip BinkMediaPlayer
# skip BinkMediaPlayerEditor
# skip BlackmagicMedia
# skip BlackmagicMediaEditor
# skip BlackmagicMediaFactory
# skip BlackmagicMediaOutput
# skip BlankPlugin
# skip BlastAuthoring
# skip BlastCore
# skip BlueprintFileUtils
# skip BlueprintMaterialTextureNodes
# skip BlueprintStats
# skip BspMode
# skip CableComponent
# skip CADInterfaces
# skip CADLibrary
# skip CADTools
# skip CameraCalibration
# skip CameraCalibrationCore
# skip CameraCalibrationCoreEditor
# skip CameraCalibrationEditor
# skip CameraShakePreviewer
# skip CascadeToNiagaraConverter
# skip ChaosCaching
# skip ChaosCachingEditor
# skip ChaosCloth
# skip ChaosClothEditor
# skip ChaosNiagara
# skip ChaosSolverEditor
# skip ChaosVehicles
# skip ChaosVehiclesEditor
# skip CharacterAI
# skip ChunkDownloader
# skip CLionSourceCodeAccess
# skip CodeEditor
# skip CodeView
# skip ColorCorrectRegions
# skip ColorCorrectRegionsEditor
# skip CommonConversationEditor
# skip CommonConversationGraph
# skip CommonConversationRuntime
# skip CommonInput
# skip CommonUI
# skip CommonUIEditor
# skip CompositePlane
# skip Composure
# skip ComposureEditor
# skip ComposureLayersEditor
# skip Concert
# skip ConcertSyncClient
# skip ConcertSyncCore
# skip ConcertSyncServer
# skip ConcertSyncTest
# skip ConcertSyncUI
# skip ConcertTakeRecorder
# skip ConcertTransport
# skip ContentBrowserAssetDataSource
# skip ContentBrowserClassDataSource
# skip ContentBrowserFileDataSource
# skip ControlRig
# skip ControlRigDeveloper
# skip ControlRigEditor
# skip CryptoKeys
# skip CryptoKeysOpenSSL
# skip CurveEditorTools
# skip CustomizableSequencerTracks
# skip CustomizableSequencerTracksEditor
# skip CustomMeshComponent
# skip DatabaseSupport
# skip DataCharts
# skip DataChartsEditor
# skip DataprepCore
# skip DataprepEditor
# skip DataprepEditorScriptingUtilities
# skip DataprepGeometryOperations
# skip DataprepLibraries
# skip DataRegistry
# skip DataRegistryEditor
# skip DatasmithC4DTranslator
# skip DatasmithCADTranslator
# skip DatasmithContent
# skip DatasmithContentEditor
# skip DatasmithCoreTechExtension
# skip DatasmithCoreTechParametricSurfaceData
# skip DatasmithDeltaGenTranslator
# skip DatasmithDispatcher
# skip DatasmithFBXTranslator
# skip DatasmithGLTFTranslator
# skip DatasmithIFCTranslator
# skip DatasmithImporter
# skip DatasmithNativeTranslator
# skip DatasmithOpenNurbsTranslator
# skip DatasmithPLMXMLTranslator
# skip DatasmithRuntime
# skip DatasmithTranslator
# skip DatasmithVREDTranslator
# skip DatasmithWireTranslator
# skip DataValidation
# skip DirectLinkTest
# skip DisasterRecoveryClient
# skip DisplayCluster
# skip DisplayClusterConfiguration
# skip DisplayClusterConfigurator
# skip DisplayClusterEditor
# skip DisplayClusterMessageInterception
# skip DisplayClusterMultiUser
index.html
# https://docs.unrealengine.com/4.27/en-US/API/Plugins/USDImporter/index.html Plugins/USDImporter/index.html
# https://docs.unrealengine.com/4.27/en-US/API/Plugins/USDMultiUser/index.html Plugins/USDMultiUser/index.html
# no class section in https://docs.unrealengine.com/4.27/en-US/API/Plugins/USDMultiUser/index.html
# https://docs.unrealengine.com/4.27/en-US/API/Plugins/USDSchemas/index.html Plugins/USDSchemas/index.html
# https://docs.unrealengine.com/4.27/en-US/API/Plugins/USDStage/index.html Plugins/USDStage/index.html
# https://docs.unrealengine.com/4.27/en-US/API/Plugins/USDStageEditor/index.html Plugins/USDStageEditor/index.html
# https://docs.unrealengine.com/4.27/en-US/API/Plugins/USDStageEditorViewModels/index.html Plugins/USDStageEditorViewModels/index.html
# https://docs.unrealengine.com/4.27/en-US/API/Plugins/USDStageImporter/index.html Plugins/USDStageImporter/index.html
# https://docs.unrealengine.com/4.27/en-US/API/Plugins/USDUtilities/index.html Plugins/USDUtilities/index.html
# https://docs.unrealengine.com/4.27/en-US/API/Plugins/VariantManager/index.html Plugins/VariantManager/index.html
# https://docs.unrealengine.com/4.27/en-US/API/Plugins/VariantManagerContent/index.html Plugins/VariantManagerContent/index.html
# https://docs.unrealengine.com/4.27/en-US/API/Plugins/VariantManagerContentEditor/index.html Plugins/VariantManagerContentEditor/index.html
# https://docs.unrealengine.com/4.27/en-US/API/Plugins/VCamCore/index.html Plugins/VCamCore/index.html
# https://docs.unrealengine.com/4.27/en-US/API/Plugins/VCamCoreEditor/index.html Plugins/VCamCoreEditor/index.html
# https://docs.unrealengine.com/4.27/en-US/API/Plugins/VCamInput/index.html Plugins/VCamInput/index.html
# https://docs.unrealengine.com/4.27/en-US/API/Plugins/VirtualCamera/index.html Plugins/VirtualCamera/index.html
# https://docs.unrealengine.com/4.27/en-US/API/Plugins/VirtualCameraEditor/index.html Plugins/VirtualCameraEditor/index.html
# no class section in https://docs.unrealengine.com/4.27/en-US/API/Plugins/VirtualCameraEditor/index.html
# https://docs.unrealengine.com/4.27/en-US/API/Plugins/VirtualHeightfieldMesh/index.html Plugins/VirtualHeightfieldMesh/index.html
# https://docs.unrealengine.com/4.27/en-US/API/Plugins/VirtualHeightfieldMeshEditor/index.html Plugins/VirtualHeightfieldMeshEditor/index.html
# https://docs.unrealengine.com/4.27/en-US/API/Plugins/VisualStudioCodeSourceCodeAccess/index.html Plugins/VisualStudioCodeSourceCodeAccess/index.html
# no class section in https://docs.unrealengine.com/4.27/en-US/API/Plugins/VisualStudioCodeSourceCodeAccess/index.html
# https://docs.unrealengine.com/4.27/en-US/API/Plugins/VisualStudioSourceCodeAccess/index.html Plugins/VisualStudioSourceCodeAccess/index.html
# no class section in https://docs.unrealengine.com/4.27/en-US/API/Plugins/VisualStudioSourceCodeAccess/index.html
# https://docs.unrealengine.com/4.27/en-US/API/Plugins/VivoxVoiceChat/index.html Plugins/VivoxVoiceChat/index.html
# https://docs.unrealengine.com/4.27/en-US/API/Plugins/Volumetrics/index.html Plugins/Volumetrics/index.html
# https://docs.unrealengine.com/4.27/en-US/API/Plugins/VPBookmark/index.html Plugins/VPBookmark/index.html
# https://docs.unrealengine.com/4.27/en-US/API/Plugins/VPBookmarkEditor/index.html Plugins/VPBookmarkEditor/index.html
# https://docs.unrealengine.com/4.27/en-US/API/Plugins/VPUtilities/index.html Plugins/VPUtilities/index.html
# https://docs.unrealengine.com/4.27/en-US/API/Plugins/VPUtilitiesEditor/index.html Plugins/VPUtilitiesEditor/index.html
# https://docs.unrealengine.com/4.27/en-US/API/Plugins/WarpUtils/index.html Plugins/WarpUtils/index.html
# https://docs.unrealengine.com/4.27/en-US/API/Plugins/Water/index.html Plugins/Water/index.html
# https://docs.unrealengine.com/4.27/en-US/API/Plugins/WaterEditor/index.html Plugins/WaterEditor/index.html
# https://docs.unrealengine.com/4.27/en-US/API/Plugins/WebAuth/index.html Plugins/WebAuth/index.html
# https://docs.unrealengine.com/4.27/en-US/API/Plugins/WebBrowserNativeProxy/index.html Plugins/WebBrowserNativeProxy/index.html
# https://docs.unrealengine.com/4.27/en-US/API/Plugins/WebBrowserWidget/index.html Plugins/WebBrowserWidget/index.html
# https://docs.unrealengine.com/4.27/en-US/API/Plugins/WebMMedia/index.html Plugins/WebMMedia/index.html
# https://docs.unrealengine.com/4.27/en-US/API/Plugins/WebMMediaEditor/index.html Plugins/WebMMediaEditor/index.html
# no class section in https://docs.unrealengine.com/4.27/en-US/API/Plugins/WebMMediaEditor/index.html
# https://docs.unrealengine.com/4.27/en-US/API/Plugins/WebMMediaFactory/index.html Plugins/WebMMediaFactory/index.html
# no class section in https://docs.unrealengine.com/4.27/en-US/API/Plugins/WebMMediaFactory/index.html
# https://docs.unrealengine.com/4.27/en-US/API/Plugins/WebMMoviePlayer/index.html Plugins/WebMMoviePlayer/index.html
# no class section in https://docs.unrealengine.com/4.27/en-US/API/Plugins/WebMMoviePlayer/index.html
# https://docs.unrealengine.com/4.27/en-US/API/Plugins/WebRemoteControl/index.html Plugins/WebRemoteControl/index.html
# https://docs.unrealengine.com/4.27/en-US/API/Plugins/WebSocketNetworking/index.html Plugins/WebSocketNetworking/index.html
# https://docs.unrealengine.com/4.27/en-US/API/Plugins/WindowsDeviceProfileSelector/index.html Plugins/WindowsDeviceProfileSelector/index.html
# no class section in https://docs.unrealengine.com/4.27/en-US/API/Plugins/WindowsDeviceProfileSelector/index.html
# https://docs.unrealengine.com/4.27/en-US/API/Plugins/WindowsMoviePlayer/index.html Plugins/WindowsMoviePlayer/index.html
# no class section in https://docs.unrealengine.com/4.27/en-US/API/Plugins/WindowsMoviePlayer/index.html
# https://docs.unrealengine.com/4.27/en-US/API/Plugins/WmfMedia/index.html Plugins/WmfMedia/index.html
# https://docs.unrealengine.com/4.27/en-US/API/Plugins/WmfMediaEditor/index.html Plugins/WmfMediaEditor/index.html
# no class section in https://docs.unrealengine.com/4.27/en-US/API/Plugins/WmfMediaEditor/index.html
# https://docs.unrealengine.com/4.27/en-US/API/Plugins/WmfMediaFactory/index.html Plugins/WmfMediaFactory/index.html
# https://docs.unrealengine.com/4.27/en-US/API/Plugins/XGEController/index.html Plugins/XGEController/index.html
# https://docs.unrealengine.com/4.27/en-US/API/Plugins/XRVisualization/index.html Plugins/XRVisualization/index.html

# %% [markdown]
# ## Let's bring them together

# %%
# Data = CrawlEveryModule()


# with open('output.json', 'w') as f:
#     json.dump(Data, f, indent=4)
